# %%
import duckdb
campaign_db = duckdb.connect(r"C:\KRESNA\ANALYSIS\Ads Analysis\DUCKDB_ADS_DATASET\campaign.duckdb")
campaign_db.sql('CALL start_ui()')
# Out:
# FloatProgress(value=0.0, layout=Layout(width='auto'), style=ProgressStyle(bar_color='black'))
# ┌──────────────────────────────────────┐
# │                result                │
# │               varchar                │
# ├──────────────────────────────────────┤
# │ UI started at http://localhost:4213/ │
# └──────────────────────────────────────┘

# %%
import duckdb
conn = duckdb.connect('md:?motherduck_token=eyJhbGciOiJIUzI1NiIsInR5cCI6IkpXVCJ9..kzUZdYuxfiw1Yzv_XsXpF5MIXogch7dcPQ3JduJLuUk')
conn.execute("ATTACH IF NOT EXISTS 'md:campaign' as campaign")
print(conn.execute('SELECT 1').df())
# Out:
#    1
# 0  1
